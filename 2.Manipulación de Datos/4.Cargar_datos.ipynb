# %%
# !pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.9.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.6.1-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.9.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 19.9 MB/s eta 0:00:00
# Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.6.1 pymongo-4.9.1

# %%
import pandas as pd
import sqlalchemy as db 
import sqlalchemy as text
from pymongo import MongoClient

# %%
engine =db.create_engine("mysql://root:root@127.0.0.1:3310/retail_db")
conn = engine.connect()

# %%
customers_df = pd.read_sql('customers',con=conn)

# %%
conn_string = 'mongodb+srv://csrcatalan:a1CIglZ7oveArUb3@cluster0.b88k0.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0'
client = MongoClient(conn_string)

# %%
db_name = client['retail_db']
collection_name = db_name['customers']

# %%
df_to_dict = customers_df.to_dict('records')
df_to_dict
# Out:
# [{'customer_id': 1,
#   'customer_fname': 'Richard',
#   'customer_lname': 'Hernandez',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '6303 Heather Plaza',
#   'customer_city': 'Brownsville',
#   'customer_state': 'TX',
#   'customer_zipcode': '78521'},
#  {'customer_id': 2,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Barrett',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '9526 Noble Embers Ridge',
#   'customer_city': 'Littleton',
#   'customer_state': 'CO',
#   'customer_zipcode': '80126'},
#  {'customer_id': 3,
#   'customer_fname': 'Ann',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '3422 Blue Pioneer Bend',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 4,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Jones',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '8324 Little Common',
#   'customer_city': 'San Marcos',
#   'customer_state': 'CA',
#   'customer_zipcode': '92069'},
#  {'customer_id': 5,
#   'customer_fname': 'Robert',
#   'customer_lname': 'Hudson',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '10 Crystal River Mall ',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 6,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '3151 Sleepy Quail Promenade',
#   'customer_city': 'Passaic',
#   'customer_state': 'NJ',
#   'customer_zipcode': '07055'},
#  {'customer_id': 7,
#   'customer_fname': 'Melissa',
#   'customer_lname': 'Wilcox',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '9453 High Concession',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 8,
#   'customer_fname': 'Megan',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '3047 Foggy Forest Plaza',
#   'customer_city': 'Lawrence',
#   'customer_state': 'MA',
#   'customer_zipcode': '01841'},
#  {'customer_id': 9,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Perez',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '3616 Quaking Street',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 10,
#   'customer_fname': 'Melissa',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '8598 Harvest Beacon Plaza',
#   'customer_city': 'Stafford',
#   'customer_state': 'VA',
#   'customer_zipcode': '22554'},
#  {'customer_id': 11,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Huffman',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '3169 Stony Woods',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 12,
#   'customer_fname': 'Christopher',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '5594 Jagged Embers By-pass',
#   'customer_city': 'San Antonio',
#   'customer_state': 'TX',
#   'customer_zipcode': '78227'},
#  {'customer_id': 13,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Baldwin',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '7922 Iron Oak Gardens',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 14,
#   'customer_fname': 'Katherine',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '5666 Hazy Pony Square',
#   'customer_city': 'Pico Rivera',
#   'customer_state': 'CA',
#   'customer_zipcode': '90660'},
#  {'customer_id': 15,
#   'customer_fname': 'Jane',
#   'customer_lname': 'Luna',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '673 Burning Glen',
#   'customer_city': 'Fontana',
#   'customer_state': 'CA',
#   'customer_zipcode': '92336'},
#  {'customer_id': 16,
#   'customer_fname': 'Tiffany',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '6651 Iron Port',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 17,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Robinson',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '1325 Noble Pike',
#   'customer_city': 'Taylor',
#   'customer_state': 'MI',
#   'customer_zipcode': '48180'},
#  {'customer_id': 18,
#   'customer_fname': 'Robert',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '2734 Hazy Butterfly Circle',
#   'customer_city': 'Martinez',
#   'customer_state': 'CA',
#   'customer_zipcode': '94553'},
#  {'customer_id': 19,
#   'customer_fname': 'Stephanie',
#   'customer_lname': 'Mitchell',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '3543 Red Treasure Bay',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 20,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Ellis',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '4703 Old Route',
#   'customer_city': 'West New York',
#   'customer_state': 'NJ',
#   'customer_zipcode': '07093'},
#  {'customer_id': 21,
#   'customer_fname': 'William',
#   'customer_lname': 'Zimmerman',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '3323 Old Willow Mall ',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 22,
#   'customer_fname': 'Joseph',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '7740 Broad Fox Villas',
#   'customer_city': 'North Bergen',
#   'customer_state': 'NJ',
#   'customer_zipcode': '07047'},
#  {'customer_id': 23,
#   'customer_fname': 'Benjamin',
#   'customer_lname': 'Duarte',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '8811 High Horse Impasse',
#   'customer_city': 'San Juan',
#   'customer_state': 'PR',
#   'customer_zipcode': '00921'},
#  {'customer_id': 24,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '9417 Emerald Towers',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 25,
#   'customer_fname': 'Paul',
#   'customer_lname': 'Richardson',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '318 Merry Creek Mountain',
#   'customer_city': 'Peoria',
#   'customer_state': 'AZ',
#   'customer_zipcode': '85345'},
#  {'customer_id': 26,
#   'customer_fname': 'Johnny',
#   'customer_lname': 'Hood',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '9576 Middle Hills Round',
#   'customer_city': 'Glenview',
#   'customer_state': 'IL',
#   'customer_zipcode': '60025'},
#  {'customer_id': 27,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Vincent',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '1768 Sleepy Zephyr Place',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 28,
#   'customer_fname': 'Timothy',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '9366 Colonial Horse Close',
#   'customer_city': 'Longview',
#   'customer_state': 'WA',
#   'customer_zipcode': '98632'},
#  {'customer_id': 29,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Humphrey',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '2469 Blue Brook Crossing',
#   'customer_city': 'Fort Worth',
#   'customer_state': 'TX',
#   'customer_zipcode': '76133'},
#  {'customer_id': 30,
#   'customer_fname': 'Barbara',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '2455 Merry Hollow',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 31,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Byrd',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '8259 Foggy Edge',
#   'customer_city': 'Albuquerque',
#   'customer_state': 'NM',
#   'customer_zipcode': '87111'},
#  {'customer_id': 32,
#   'customer_fname': 'Alice',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '2082 Hidden Green',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 33,
#   'customer_fname': 'Adam',
#   'customer_lname': 'Petersen',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '9768 Noble Horse Heights',
#   'customer_city': 'Norfolk',
#   'customer_state': 'VA',
#   'customer_zipcode': '23503'},
#  {'customer_id': 34,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '3330 Easy Berry Range',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 35,
#   'customer_fname': 'Margaret',
#   'customer_lname': 'Wright',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '9456 Sleepy Jetty',
#   'customer_city': 'Oceanside',
#   'customer_state': 'CA',
#   'customer_zipcode': '92056'},
#  {'customer_id': 36,
#   'customer_fname': 'Michelle',
#   'customer_lname': 'Carey',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '6336 Fallen Village',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 37,
#   'customer_fname': 'Virginia',
#   'customer_lname': 'Conrad',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '6115 Indian Beacon Close',
#   'customer_city': 'Norfolk',
#   'customer_state': 'VA',
#   'customer_zipcode': '23503'},
#  {'customer_id': 38,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '2805 Crystal Moor',
#   'customer_city': 'Opelousas',
#   'customer_state': 'LA',
#   'customer_zipcode': '70570'},
#  {'customer_id': 39,
#   'customer_fname': 'Juan',
#   'customer_lname': 'Mckinney',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '7274 Blue Wagon  Villas',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 40,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '7358 Rocky Villas',
#   'customer_city': 'Long Beach',
#   'customer_state': 'CA',
#   'customer_zipcode': '90805'},
#  {'customer_id': 41,
#   'customer_fname': 'Victoria',
#   'customer_lname': 'Mason',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '7869 Crystal View Villas',
#   'customer_city': 'Brooklyn',
#   'customer_state': 'NY',
#   'customer_zipcode': '11230'},
#  {'customer_id': 42,
#   'customer_fname': 'Ethan',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '7533 Thunder Wagon  Beach',
#   'customer_city': 'Duluth',
#   'customer_state': 'GA',
#   'customer_zipcode': '30096'},
#  {'customer_id': 43,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Herring',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '4575 Thunder Dale',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 44,
#   'customer_fname': 'Howard',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '1356 Easy Plaza',
#   'customer_city': 'Napa',
#   'customer_state': 'CA',
#   'customer_zipcode': '94558'},
#  {'customer_id': 45,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Nunez',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '1229 Bright Robin Corners',
#   'customer_city': 'Denver',
#   'customer_state': 'CO',
#   'customer_zipcode': '80231'},
#  {'customer_id': 46,
#   'customer_fname': 'Jennifer',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '5463 Rocky Autoroute',
#   'customer_city': 'Freeport',
#   'customer_state': 'NY',
#   'customer_zipcode': '11520'},
#  {'customer_id': 47,
#   'customer_fname': 'Lori',
#   'customer_lname': 'Fuller',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '357 Noble Lane',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 48,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Cowan',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '1040 Hazy Timber Lookout',
#   'customer_city': 'Strongsville',
#   'customer_state': 'OH',
#   'customer_zipcode': '44136'},
#  {'customer_id': 49,
#   'customer_fname': 'Martha',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '7449 Merry Chase',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 50,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Kim',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '938 Rustic Pine Ridge',
#   'customer_city': 'San Bernardino',
#   'customer_state': 'CA',
#   'customer_zipcode': '92410'},
#  {'customer_id': 51,
#   'customer_fname': 'Jessica',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '8344 Dewy Fawn Farms',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 52,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Lawson',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '65 Silent Inlet',
#   'customer_city': 'Chicago',
#   'customer_state': 'IL',
#   'customer_zipcode': '60622'},
#  {'customer_id': 53,
#   'customer_fname': 'Katherine',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '975 Honey Loop',
#   'customer_city': 'Roswell',
#   'customer_state': 'GA',
#   'customer_zipcode': '30075'},
#  {'customer_id': 54,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Olson',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '7333 Cinder Way',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 55,
#   'customer_fname': 'Janet',
#   'customer_lname': 'Farley',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '6512 Middle Parade',
#   'customer_city': 'Phoenix',
#   'customer_state': 'AZ',
#   'customer_zipcode': '85029'},
#  {'customer_id': 56,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Kaiser',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '7554 Stony Goose Crossing',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 57,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '57 High Villas',
#   'customer_city': 'Baltimore',
#   'customer_state': 'MD',
#   'customer_zipcode': '21229'},
#  {'customer_id': 58,
#   'customer_fname': 'Michael',
#   'customer_lname': 'Edwards',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '4770 Blue Pines',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 59,
#   'customer_fname': 'Douglas',
#   'customer_lname': 'James',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '2306 Green Lane',
#   'customer_city': 'Sunnyvale',
#   'customer_state': 'CA',
#   'customer_zipcode': '94086'},
#  {'customer_id': 60,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Gutierrez',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '8632 Bright Route',
#   'customer_city': 'Webster',
#   'customer_state': 'NY',
#   'customer_zipcode': '14580'},
#  {'customer_id': 61,
#   'customer_fname': 'Margaret',
#   'customer_lname': 'Summers',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '8963 Hidden Panda Meadow',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 62,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Oneal',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '2659 Jagged Rabbit View',
#   'customer_city': 'Brooklyn',
#   'customer_state': 'NY',
#   'customer_zipcode': '11223'},
#  {'customer_id': 63,
#   'customer_fname': 'Aaron',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '2265 Foggy Lagoon Bend',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 64,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Reynolds',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '2407 Gentle Woods',
#   'customer_city': 'Chicago',
#   'customer_state': 'IL',
#   'customer_zipcode': '60647'},
#  {'customer_id': 65,
#   'customer_fname': 'Jennifer',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '7126 Shady Bluff Promenade',
#   'customer_city': 'Princeton',
#   'customer_state': 'NJ',
#   'customer_zipcode': '08540'},
#  {'customer_id': 66,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Booth',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '8824 Noble View Valley',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 67,
#   'customer_fname': 'Samantha',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '7869 Wishing Anchor Court',
#   'customer_city': 'Chicago',
#   'customer_state': 'IL',
#   'customer_zipcode': '60619'},
#  {'customer_id': 68,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Oneal',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '376 Silver Terrace',
#   'customer_city': 'Peoria',
#   'customer_state': 'AZ',
#   'customer_zipcode': '85345'},
#  {'customer_id': 69,
#   'customer_fname': 'Megan',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '7796 Thunder Forest Villas',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 70,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Simmons',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '5553 Cinder Harbour',
#   'customer_city': 'Los Angeles',
#   'customer_state': 'CA',
#   'customer_zipcode': '90042'},
#  {'customer_id': 71,
#   'customer_fname': 'Charles',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '6140 Pleasant Dale Farm',
#   'customer_city': 'Philadelphia',
#   'customer_state': 'PA',
#   'customer_zipcode': '19145'},
#  {'customer_id': 72,
#   'customer_fname': 'Frank',
#   'customer_lname': 'Gillespie',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '5332 Heather Hills Isle',
#   'customer_city': 'Vista',
#   'customer_state': 'CA',
#   'customer_zipcode': '92084'},
#  {'customer_id': 73,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '8247 Little Cider Close',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 74,
#   'customer_fname': 'Alice',
#   'customer_lname': 'Rush',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '409 Iron Park',
#   'customer_city': 'Jacksonville',
#   'customer_state': 'NC',
#   'customer_zipcode': '28540'},
#  {'customer_id': 75,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '1510 Broad Rise Expressway',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 76,
#   'customer_fname': 'Joseph',
#   'customer_lname': 'Young',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '7605 Tawny Horse Falls',
#   'customer_city': 'Los Angeles',
#   'customer_state': 'CA',
#   'customer_zipcode': '90016'},
#  {'customer_id': 77,
#   'customer_fname': 'Shirley',
#   'customer_lname': 'Dalton',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '1021 Silver Log Cape',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 78,
#   'customer_fname': 'Jeremy',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '2714 Dewy Bay',
#   'customer_city': 'Parkville',
#   'customer_state': 'MD',
#   'customer_zipcode': '21234'},
#  {'customer_id': 79,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Watkins',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '1315 Honey Rabbit Link',
#   'customer_city': 'Knoxville',
#   'customer_state': 'TN',
#   'customer_zipcode': '37922'},
#  {'customer_id': 80,
#   'customer_fname': 'Joe',
#   'customer_lname': 'Parsons',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '3891 Broad Line',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 81,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '8434 Honey Pines',
#   'customer_city': 'Ithaca',
#   'customer_state': 'NY',
#   'customer_zipcode': '14850'},
#  {'customer_id': 82,
#   'customer_fname': 'Jonathan',
#   'customer_lname': 'Cook',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '7885 Sleepy Cove',
#   'customer_city': 'San Antonio',
#   'customer_state': 'TX',
#   'customer_zipcode': '78240'},
#  {'customer_id': 83,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Wong',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '8584 Lazy Via',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 84,
#   'customer_fname': 'Douglas',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '6540 Emerald Turnabout',
#   'customer_city': 'Tampa',
#   'customer_state': 'FL',
#   'customer_zipcode': '33624'},
#  {'customer_id': 85,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Perez',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '5104 Iron Log Limits',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 86,
#   'customer_fname': 'John',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '8780 Colonial Orchard',
#   'customer_city': 'Fort Worth',
#   'customer_state': 'TX',
#   'customer_zipcode': '76106'},
#  {'customer_id': 87,
#   'customer_fname': 'Gloria',
#   'customer_lname': 'Brown',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '3996 Crystal Zephyr Swale',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 88,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Henry',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '7262 Cotton Arbor',
#   'customer_city': 'Atlanta',
#   'customer_state': 'GA',
#   'customer_zipcode': '30318'},
#  {'customer_id': 89,
#   'customer_fname': 'Sean',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '9126 Wishing Expressway',
#   'customer_city': 'Escondido',
#   'customer_state': 'CA',
#   'customer_zipcode': '92027'},
#  {'customer_id': 90,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Hurley',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '6640 Sunny Via',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 91,
#   'customer_fname': 'Ashley',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '4515 Golden Manor',
#   'customer_city': 'Spring',
#   'customer_state': 'TX',
#   'customer_zipcode': '77379'},
#  {'customer_id': 92,
#   'customer_fname': 'Alexander',
#   'customer_lname': 'Medina',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '2805 Dewy Impasse',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 93,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Robbins',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '456 Colonial Glen',
#   'customer_city': 'Annapolis',
#   'customer_state': 'MD',
#   'customer_zipcode': '21401'},
#  {'customer_id': 94,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '921 Broad Chase',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 95,
#   'customer_fname': 'Susan',
#   'customer_lname': 'Williams',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '3587 Thunder Rise',
#   'customer_city': 'Hyattsville',
#   'customer_state': 'MD',
#   'customer_zipcode': '20783'},
#  {'customer_id': 96,
#   'customer_fname': 'Virginia',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '6080 Blue Close',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 97,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Rhodes',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '1463 Silver Mountain Gate',
#   'customer_city': 'Phoenix',
#   'customer_state': 'AZ',
#   'customer_zipcode': '85008'},
#  {'customer_id': 98,
#   'customer_fname': 'William',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '4592 Grand Timber Ramp',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 99,
#   'customer_fname': 'Betty',
#   'customer_lname': 'Munoz',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '9761 Green Jetty',
#   'customer_city': 'Las Vegas',
#   'customer_state': 'NV',
#   'customer_zipcode': '89123'},
#  {'customer_id': 100,
#   'customer_fname': 'George',
#   'customer_lname': 'Barrett',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '4110 Silent Pointe',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 101,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Briggs',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '8342 Crystal Drive',
#   'customer_city': 'Dorchester Center',
#   'customer_state': 'MA',
#   'customer_zipcode': '02124'},
#  {'customer_id': 102,
#   'customer_fname': 'Gregory',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '5393 Hidden Glade',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 103,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Williams',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '4501 Cinder Dell',
#   'customer_city': 'Broomfield',
#   'customer_state': 'CO',
#   'customer_zipcode': '80020'},
#  {'customer_id': 104,
#   'customer_fname': 'Debra',
#   'customer_lname': 'Wood',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '8263 Harvest Estates',
#   'customer_city': 'Saint Paul',
#   'customer_state': 'MN',
#   'customer_zipcode': '55112'},
#  {'customer_id': 105,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '8696 Fallen Cloud Circle',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 106,
#   'customer_fname': 'Lauren',
#   'customer_lname': 'Freeman',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '2783 Foggy Mews',
#   'customer_city': 'Napa',
#   'customer_state': 'CA',
#   'customer_zipcode': '94558'},
#  {'customer_id': 107,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Weaver',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '1449 Amber Island',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 108,
#   'customer_fname': 'Joshua',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '4587 Noble Zephyr Promenade',
#   'customer_city': 'Bronx',
#   'customer_state': 'NY',
#   'customer_zipcode': '10462'},
#  {'customer_id': 109,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Thompson',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '8662 Clear Nectar Mall ',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 110,
#   'customer_fname': 'David',
#   'customer_lname': 'Miranda',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '1491 Little Robin Way',
#   'customer_city': 'Beaverton',
#   'customer_state': 'OR',
#   'customer_zipcode': '97006'},
#  {'customer_id': 111,
#   'customer_fname': 'Frank',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '8736 Hazy River Manor',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 112,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Daniels',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '9814 Blue Anchor Dell',
#   'customer_city': 'Middletown',
#   'customer_state': 'OH',
#   'customer_zipcode': '45044'},
#  {'customer_id': 113,
#   'customer_fname': 'Patricia',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '2457 Blue Hills Heights',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 114,
#   'customer_fname': 'Alice',
#   'customer_lname': 'Warner',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '4566 Burning Deer Meadow',
#   'customer_city': 'Bellflower',
#   'customer_state': 'CA',
#   'customer_zipcode': '90706'},
#  {'customer_id': 115,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '1613 Broad Beach',
#   'customer_city': 'West Covina',
#   'customer_state': 'CA',
#   'customer_zipcode': '91790'},
#  {'customer_id': 116,
#   'customer_fname': 'John',
#   'customer_lname': 'Hill',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '3996 Honey Grove Place',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 117,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '6063 Golden Point',
#   'customer_city': 'La Crosse',
#   'customer_state': 'WI',
#   'customer_zipcode': '54601'},
#  {'customer_id': 118,
#   'customer_fname': 'Katherine',
#   'customer_lname': 'Olson',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '9530 Little Fox Towers',
#   'customer_city': 'Ogden',
#   'customer_state': 'UT',
#   'customer_zipcode': '84404'},
#  {'customer_id': 119,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Rosario',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '5488 Thunder Fox Extension',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 120,
#   'customer_fname': 'Nancy',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '7840 Umber Sky Villas',
#   'customer_city': 'Bronx',
#   'customer_state': 'NY',
#   'customer_zipcode': '10461'},
#  {'customer_id': 121,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Yoder',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '3570 Crystal Cider Circuit',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 122,
#   'customer_fname': 'Karen',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '7573 Cozy Goose Road',
#   'customer_city': 'Cincinnati',
#   'customer_state': 'OH',
#   'customer_zipcode': '45238'},
#  {'customer_id': 123,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Mann',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '7676 Colonial Towers',
#   'customer_city': 'Bend',
#   'customer_state': 'OR',
#   'customer_zipcode': '97701'},
#  {'customer_id': 124,
#   'customer_fname': 'Judy',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '911 Sleepy Cloud Carrefour',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 125,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Gallagher',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '9831 Sunny Cloud Valley',
#   'customer_city': 'Oxnard',
#   'customer_state': 'CA',
#   'customer_zipcode': '93030'},
#  {'customer_id': 126,
#   'customer_fname': 'Austin',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '852 Hazy Gate Circuit',
#   'customer_city': 'Amarillo',
#   'customer_state': 'TX',
#   'customer_zipcode': '79109'},
#  {'customer_id': 127,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Martin',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '437 Cozy Log Range',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 128,
#   'customer_fname': 'Rose',
#   'customer_lname': 'Lopez',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '9557 Harvest Mews',
#   'customer_city': 'Augusta',
#   'customer_state': 'GA',
#   'customer_zipcode': '30906'},
#  {'customer_id': 129,
#   'customer_fname': 'Crystal',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '3688 Thunder Prairie Heights',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 130,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Holland',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '9897 Sunny Via',
#   'customer_city': 'Aurora',
#   'customer_state': 'IL',
#   'customer_zipcode': '60504'},
#  {'customer_id': 131,
#   'customer_fname': 'Brenda',
#   'customer_lname': 'Cline',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '8632 Bright Route',
#   'customer_city': 'Methuen',
#   'customer_state': 'MA',
#   'customer_zipcode': '01844'},
#  {'customer_id': 132,
#   'customer_fname': 'Eric',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '1131 Cotton Grounds',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 133,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Lopez',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '948 Thunder Gate Beach',
#   'customer_city': 'Brooklyn',
#   'customer_state': 'NY',
#   'customer_zipcode': '11219'},
#  {'customer_id': 134,
#   'customer_fname': 'Donna',
#   'customer_lname': 'Gomez',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '1690 Cinder Deer Chase',
#   'customer_city': 'Brooklyn',
#   'customer_state': 'NY',
#   'customer_zipcode': '11224'},
#  {'customer_id': 135,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '9624 Hidden Villas',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 136,
#   'customer_fname': 'Ryan',
#   'customer_lname': 'Griffin',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '7897 Stony Thicket',
#   'customer_city': 'Lynn',
#   'customer_state': 'MA',
#   'customer_zipcode': '01902'},
#  {'customer_id': 137,
#   'customer_fname': 'Jonathan',
#   'customer_lname': 'Perkins',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '182 Bright Embers Cove',
#   'customer_city': 'Broken Arrow',
#   'customer_state': 'OK',
#   'customer_zipcode': '74012'},
#  {'customer_id': 138,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Dawson',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '9544 Noble Spring Route',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 139,
#   'customer_fname': 'Daniel',
#   'customer_lname': 'Maxwell',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '9468 Red Corner',
#   'customer_city': 'San Diego',
#   'customer_state': 'CA',
#   'customer_zipcode': '92104'},
#  {'customer_id': 140,
#   'customer_fname': 'Amanda',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '5712 Heather Rise',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 141,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Mcmahon',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '1526 Broad Mountain Plaza',
#   'customer_city': 'Brooklyn',
#   'customer_state': 'NY',
#   'customer_zipcode': '11203'},
#  {'customer_id': 142,
#   'customer_fname': 'Heather',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '814 Jagged Cape',
#   'customer_city': 'Opa Locka',
#   'customer_state': 'FL',
#   'customer_zipcode': '33055'},
#  {'customer_id': 143,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Byrd',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '7793 Round Oak Key',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 144,
#   'customer_fname': 'David',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '8289 Stony Thicket',
#   'customer_city': 'Bronx',
#   'customer_state': 'NY',
#   'customer_zipcode': '10462'},
#  {'customer_id': 145,
#   'customer_fname': 'Joan',
#   'customer_lname': 'Walters',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '8314 Burning Circuit',
#   'customer_city': 'Dayton',
#   'customer_state': 'OH',
#   'customer_zipcode': '45424'},
#  {'customer_id': 146,
#   'customer_fname': 'Amber',
#   'customer_lname': 'Mercado',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '14 Dusty Lake Beach',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 147,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '443 Jagged Lane',
#   'customer_city': 'Hanover',
#   'customer_state': 'PA',
#   'customer_zipcode': '17331'},
#  {'customer_id': 148,
#   'customer_fname': 'Stephanie',
#   'customer_lname': 'Richards',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '245 Lost Way',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 149,
#   'customer_fname': 'Shirley',
#   'customer_lname': 'Mcclain',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '9729 Emerald Pony Mount',
#   'customer_city': 'Colton',
#   'customer_state': 'CA',
#   'customer_zipcode': '92324'},
#  {'customer_id': 150,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '5593 Indian Trail',
#   'customer_city': 'Union',
#   'customer_state': 'NJ',
#   'customer_zipcode': '07083'},
#  {'customer_id': 151,
#   'customer_fname': 'Lisa',
#   'customer_lname': 'Shaw',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '9772 Noble Prairie Quay',
#   'customer_city': 'Richmond',
#   'customer_state': 'TX',
#   'customer_zipcode': '77469'},
#  {'customer_id': 152,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '8333 Red Passage',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 153,
#   'customer_fname': 'Andrew',
#   'customer_lname': 'Marshall',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '8428 Blue Prairie Farm',
#   'customer_city': 'Hollywood',
#   'customer_state': 'FL',
#   'customer_zipcode': '33021'},
#  {'customer_id': 154,
#   'customer_fname': 'Emily',
#   'customer_lname': 'May',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '6697 Thunder Dale Downs',
#   'customer_city': 'Brandon',
#   'customer_state': 'FL',
#   'customer_zipcode': '33511'},
#  {'customer_id': 155,
#   'customer_fname': 'Brittany',
#   'customer_lname': 'Juarez',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '1809 Lost Pine Ledge',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 156,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '2291 Thunder Leaf Corners',
#   'customer_city': 'Los Angeles',
#   'customer_state': 'CA',
#   'customer_zipcode': '90001'},
#  {'customer_id': 157,
#   'customer_fname': 'Catherine',
#   'customer_lname': 'Chan',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '7125 Silent Expressway',
#   'customer_city': 'Citrus Heights',
#   'customer_state': 'CA',
#   'customer_zipcode': '95610'},
#  {'customer_id': 158,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '5517 Jagged Hollow',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 159,
#   'customer_fname': 'John',
#   'customer_lname': 'Love',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '5002 High Bank',
#   'customer_city': 'Corona',
#   'customer_state': 'NY',
#   'customer_zipcode': '11368'},
#  {'customer_id': 160,
#   'customer_fname': 'Ashley',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '3271 Amber Downs',
#   'customer_city': 'Brooklyn',
#   'customer_state': 'NY',
#   'customer_zipcode': '11229'},
#  {'customer_id': 161,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '6889 Pleasant Mount',
#   'customer_city': 'Hialeah',
#   'customer_state': 'FL',
#   'customer_zipcode': '33010'},
#  {'customer_id': 162,
#   'customer_fname': 'John',
#   'customer_lname': 'Garcia',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '5452 Jagged Green',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 163,
#   'customer_fname': 'Austin',
#   'customer_lname': 'Diaz',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '6843 Dusty Log Edge',
#   'customer_city': 'Rio Rancho',
#   'customer_state': 'NM',
#   'customer_zipcode': '87124'},
#  {'customer_id': 164,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Carlson',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '4527 Silent Fawn Wharf',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 165,
#   'customer_fname': 'Joseph',
#   'customer_lname': 'Ewing',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '7129 Fallen Trace',
#   'customer_city': 'Antioch',
#   'customer_state': 'CA',
#   'customer_zipcode': '94509'},
#  {'customer_id': 166,
#   'customer_fname': 'Steven',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '2805 Indian Passage',
#   'customer_city': 'Florissant',
#   'customer_state': 'MO',
#   'customer_zipcode': '63031'},
#  {'customer_id': 167,
#   'customer_fname': 'Stephanie',
#   'customer_lname': 'Rodriguez',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '923 Little Bend',
#   'customer_city': 'Columbus',
#   'customer_state': 'OH',
#   'customer_zipcode': '43228'},
#  {'customer_id': 168,
#   'customer_fname': 'Eric',
#   'customer_lname': 'Morris',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '295 Quaking Timber By-pass',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 169,
#   'customer_fname': 'Debra',
#   'customer_lname': 'Mccarthy',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '3216 Rocky Centre',
#   'customer_city': 'Bronx',
#   'customer_state': 'NY',
#   'customer_zipcode': '10466'},
#  {'customer_id': 170,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '1996 Easy Parade',
#   'customer_city': 'Broomfield',
# ...
#   'customer_state': 'MI',
#   'customer_zipcode': '49509'},
#  {'customer_id': 945,
#   'customer_fname': 'Carl',
#   'customer_lname': 'Reynolds',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '1828 Iron Goose Mount',
#   'customer_city': 'Indio',
#   'customer_state': 'CA',
#   'customer_zipcode': '92201'},
#  {'customer_id': 946,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '7324 Wishing Rise Loop',
#   'customer_city': 'La Mesa',
#   'customer_state': 'CA',
#   'customer_zipcode': '91941'},
#  {'customer_id': 947,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Henry',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '4320 Iron Highlands',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 948,
#   'customer_fname': 'Michelle',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '2437 Silver Brook Heights',
#   'customer_city': 'Lawrence',
#   'customer_state': 'MA',
#   'customer_zipcode': '01841'},
#  {'customer_id': 949,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Sawyer',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '9181 Colonial Bear Lookout',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 950,
#   'customer_fname': 'Jordan',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '4579 Sunny Link',
#   'customer_city': 'Las Vegas',
#   'customer_state': 'NV',
#   'customer_zipcode': '89103'},
#  {'customer_id': 951,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Young',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '5234 Grand Pioneer Link',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 952,
#   'customer_fname': 'Jack',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '5004 High Grove Lane',
#   'customer_city': 'Hesperia',
#   'customer_state': 'CA',
#   'customer_zipcode': '92345'},
#  {'customer_id': 953,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Mills',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '5937 Blue Pony Square',
#   'customer_city': 'Philadelphia',
#   'customer_state': 'PA',
#   'customer_zipcode': '19140'},
#  {'customer_id': 954,
#   'customer_fname': 'Brandon',
#   'customer_lname': 'Fitzgerald',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '6894 Heather Estates',
#   'customer_city': 'Richmond',
#   'customer_state': 'TX',
#   'customer_zipcode': '77469'},
#  {'customer_id': 955,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Marks',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '5424 Wishing Wagon  Bank',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 956,
#   'customer_fname': 'Karen',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '5407 Hazy Hills Point',
#   'customer_city': 'Bronx',
#   'customer_state': 'NY',
#   'customer_zipcode': '10473'},
#  {'customer_id': 957,
#   'customer_fname': 'Eric',
#   'customer_lname': 'Jones',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '987 Blue Impasse',
#   'customer_city': 'Stockton',
#   'customer_state': 'CA',
#   'customer_zipcode': '95206'},
#  {'customer_id': 958,
#   'customer_fname': 'Peter',
#   'customer_lname': 'Acosta',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '1761 Noble Barn Heath',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 959,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '2749 Green Cider Green',
#   'customer_city': 'Tempe',
#   'customer_state': 'AZ',
#   'customer_zipcode': '85283'},
#  {'customer_id': 960,
#   'customer_fname': 'Michael',
#   'customer_lname': 'Mcdonald',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '7002 Blue Place',
#   'customer_city': 'New Bedford',
#   'customer_state': 'MA',
#   'customer_zipcode': '02740'},
#  {'customer_id': 961,
#   'customer_fname': 'David',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '779 Old Anchor View',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 962,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Bowers',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '1490 Silver Canyon',
#   'customer_city': 'Saint Peters',
#   'customer_state': 'MO',
#   'customer_zipcode': '63376'},
#  {'customer_id': 963,
#   'customer_fname': 'Eugene',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '5382 Hazy Pathway',
#   'customer_city': 'Toms River',
#   'customer_state': 'NJ',
#   'customer_zipcode': '08753'},
#  {'customer_id': 964,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Frazier',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '7505 Silent Spring Acres',
#   'customer_city': 'New York',
#   'customer_state': 'NY',
#   'customer_zipcode': '10027'},
#  {'customer_id': 965,
#   'customer_fname': 'Sean',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '3779 Dewy Villas',
#   'customer_city': 'Jonesboro',
#   'customer_state': 'AR',
#   'customer_zipcode': '72401'},
#  {'customer_id': 966,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Buchanan',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '6315 Quiet Willow Vale',
#   'customer_city': 'Los Angeles',
#   'customer_state': 'CA',
#   'customer_zipcode': '90043'},
#  {'customer_id': 967,
#   'customer_fname': 'Madison',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '8688 Fallen Anchor Lookout',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 968,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Larson',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '6289 Tawny Range',
#   'customer_city': 'Cleveland',
#   'customer_state': 'OH',
#   'customer_zipcode': '44130'},
#  {'customer_id': 969,
#   'customer_fname': 'Rose',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '4804 Silent Butterfly Way',
#   'customer_city': 'Bakersfield',
#   'customer_state': 'CA',
#   'customer_zipcode': '93304'},
#  {'customer_id': 970,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Alvarez',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '6908 Middle Green',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 971,
#   'customer_fname': 'Jacqueline',
#   'customer_lname': 'Krueger',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '437 Cozy Log Range',
#   'customer_city': 'Douglasville',
#   'customer_state': 'GA',
#   'customer_zipcode': '30135'},
#  {'customer_id': 972,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '2287 Thunder Pony Nook',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 973,
#   'customer_fname': 'Linda',
#   'customer_lname': 'Hart',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '529 Noble Oak End',
#   'customer_city': 'Cleveland',
#   'customer_state': 'OH',
#   'customer_zipcode': '44105'},
#  {'customer_id': 974,
#   'customer_fname': 'George',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '7074 Crystal Parade',
#   'customer_city': 'Fresno',
#   'customer_state': 'CA',
#   'customer_zipcode': '93727'},
#  {'customer_id': 975,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Willis',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '7953 Bright Pioneer Crescent',
#   'customer_city': 'Saginaw',
#   'customer_state': 'MI',
#   'customer_zipcode': '48601'},
#  {'customer_id': 976,
#   'customer_fname': 'Shirley',
#   'customer_lname': 'Henson',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '4778 Little Creek Bay',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 977,
#   'customer_fname': 'Virginia',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '7262 Emerald Boulevard',
#   'customer_city': 'Garden Grove',
#   'customer_state': 'CA',
#   'customer_zipcode': '92840'},
#  {'customer_id': 978,
#   'customer_fname': 'Nicholas',
#   'customer_lname': 'Peters',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '1669 Middle Common',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 979,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '9995 High Robin Pointe',
#   'customer_city': 'Austin',
#   'customer_state': 'TX',
#   'customer_zipcode': '78745'},
#  {'customer_id': 980,
#   'customer_fname': 'James',
#   'customer_lname': 'Harper',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '7746 Hazy Prairie Drive',
#   'customer_city': 'San Jose',
#   'customer_state': 'CA',
#   'customer_zipcode': '95112'},
#  {'customer_id': 981,
#   'customer_fname': 'Christine',
#   'customer_lname': 'Schwartz',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '3244 Misty Leaf Inlet',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 982,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Robbins',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '4900 Dusty Line',
#   'customer_city': 'New Albany',
#   'customer_state': 'IN',
#   'customer_zipcode': '47150'},
#  {'customer_id': 983,
#   'customer_fname': 'Michael',
#   'customer_lname': 'Richmond',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '5645 Sunny Spring Gate',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 984,
#   'customer_fname': 'Amy',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '4696 Red Wharf',
#   'customer_city': 'Chicago',
#   'customer_state': 'IL',
#   'customer_zipcode': '60617'},
#  {'customer_id': 985,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Martinez',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '7790 Green Berry Gate',
#   'customer_city': 'Richmond',
#   'customer_state': 'IN',
#   'customer_zipcode': '47374'},
#  {'customer_id': 986,
#   'customer_fname': 'Catherine',
#   'customer_lname': 'Hawkins',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '3651 Rustic Cape',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 987,
#   'customer_fname': 'Cheryl',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '9611 Thunder Loop',
#   'customer_city': 'Albuquerque',
#   'customer_state': 'NM',
#   'customer_zipcode': '87111'},
#  {'customer_id': 988,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Brady',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '9413 Misty Harbour',
#   'customer_city': 'Pittsfield',
#   'customer_state': 'MA',
#   'customer_zipcode': '01201'},
#  {'customer_id': 989,
#   'customer_fname': 'Helen',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '1914 Blue Autumn Harbour',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 990,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Ellison',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '4260 Silent Blossom Isle',
#   'customer_city': 'Merced',
#   'customer_state': 'CA',
#   'customer_zipcode': '95340'},
#  {'customer_id': 991,
#   'customer_fname': 'John',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '7767 Hidden Place',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 992,
#   'customer_fname': 'Randy',
#   'customer_lname': 'Brown',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '4720 Noble Hills Wynd',
#   'customer_city': 'New York',
#   'customer_state': 'NY',
#   'customer_zipcode': '10016'},
#  {'customer_id': 993,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Davis',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '1202 Quaking Embers Link',
#   'customer_city': 'Fairfield',
#   'customer_state': 'OH',
#   'customer_zipcode': '45014'},
#  {'customer_id': 994,
#   'customer_fname': 'Lisa',
#   'customer_lname': 'Massey',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '1945 Iron Panda Circle',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 995,
#   'customer_fname': 'Helen',
#   'customer_lname': 'Hinton',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '4951 Shady Spring Path',
#   'customer_city': 'Richmond',
#   'customer_state': 'IN',
#   'customer_zipcode': '47374'},
#  {'customer_id': 996,
#   'customer_fname': 'Amanda',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '7007 Golden Edge',
#   'customer_city': 'Austin',
#   'customer_state': 'TX',
#   'customer_zipcode': '78753'},
#  {'customer_id': 997,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Price',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '2556 Wishing Zephyr Turnabout',
#   'customer_city': 'Caguas',
#   'customer_state': 'PR',
#   'customer_zipcode': '00725'},
#  {'customer_id': 998,
#   'customer_fname': 'Steven',
#   'customer_lname': 'Salinas',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '6091 Harvest Bluff View',
#   'customer_city': 'Anaheim',
#   'customer_state': 'CA',
#   'customer_zipcode': '92805'},
#  {'customer_id': 999,
#   'customer_fname': 'Mary',
#   'customer_lname': 'Stephenson',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '9557 Harvest Mews',
#   'customer_city': 'Saint Paul',
#   'customer_state': 'MN',
#   'customer_zipcode': '55124'},
#  {'customer_id': 1000,
#   'customer_fname': 'James',
#   'customer_lname': 'Smith',
#   'customer_email': 'XXXXXXXXX',
#   'customer_password': 'XXXXXXXXX',
#   'customer_street': '3627 Lost Butterfly Drive',
#   'customer_city': 'Freeport',
#   'customer_state': 'NY',
#   'customer_zipcode': '11520'},
#  ...]

# %%
collection_name.insert_many(df_to_dict)
# Out:
# InsertManyResult([ObjectId('66ecd774cdceed4ae0773d49'), ObjectId('66ecd774cdceed4ae0773d4a'), ObjectId('66ecd774cdceed4ae0773d4b'), ObjectId('66ecd774cdceed4ae0773d4c'), ObjectId('66ecd774cdceed4ae0773d4d'), ObjectId('66ecd774cdceed4ae0773d4e'), ObjectId('66ecd774cdceed4ae0773d4f'), ObjectId('66ecd774cdceed4ae0773d50'), ObjectId('66ecd774cdceed4ae0773d51'), ObjectId('66ecd774cdceed4ae0773d52'), ObjectId('66ecd774cdceed4ae0773d53'), ObjectId('66ecd774cdceed4ae0773d54'), ObjectId('66ecd774cdceed4ae0773d55'), ObjectId('66ecd774cdceed4ae0773d56'), ObjectId('66ecd774cdceed4ae0773d57'), ObjectId('66ecd774cdceed4ae0773d58'), ObjectId('66ecd774cdceed4ae0773d59'), ObjectId('66ecd774cdceed4ae0773d5a'), ObjectId('66ecd774cdceed4ae0773d5b'), ObjectId('66ecd774cdceed4ae0773d5c'), ObjectId('66ecd774cdceed4ae0773d5d'), ObjectId('66ecd774cdceed4ae0773d5e'), ObjectId('66ecd774cdceed4ae0773d5f'), ObjectId('66ecd774cdceed4ae0773d60'), ObjectId('66ecd774cdceed4ae0773d61'), ObjectId('66ecd774cdceed4ae0773d62'), ObjectId('66ecd774cdceed4ae0773d63'), ObjectId('66ecd774cdceed4ae0773d64'), ObjectId('66ecd774cdceed4ae0773d65'), ObjectId('66ecd774cdceed4ae0773d66'), ObjectId('66ecd774cdceed4ae0773d67'), ObjectId('66ecd774cdceed4ae0773d68'), ObjectId('66ecd774cdceed4ae0773d69'), ObjectId('66ecd774cdceed4ae0773d6a'), ObjectId('66ecd774cdceed4ae0773d6b'), ObjectId('66ecd774cdceed4ae0773d6c'), ObjectId('66ecd774cdceed4ae0773d6d'), ObjectId('66ecd774cdceed4ae0773d6e'), ObjectId('66ecd774cdceed4ae0773d6f'), ObjectId('66ecd774cdceed4ae0773d70'), ObjectId('66ecd774cdceed4ae0773d71'), ObjectId('66ecd774cdceed4ae0773d72'), ObjectId('66ecd774cdceed4ae0773d73'), ObjectId('66ecd774cdceed4ae0773d74'), ObjectId('66ecd774cdceed4ae0773d75'), ObjectId('66ecd774cdceed4ae0773d76'), ObjectId('66ecd774cdceed4ae0773d77'), ObjectId('66ecd774cdceed4ae0773d78'), ObjectId('66ecd774cdceed4ae0773d79'), ObjectId('66ecd774cdceed4ae0773d7a'), ObjectId('66ecd774cdceed4ae0773d7b'), ObjectId('66ecd774cdceed4ae0773d7c'), ObjectId('66ecd774cdceed4ae0773d7d'), ObjectId('66ecd774cdceed4ae0773d7e'), ObjectId('66ecd774cdceed4ae0773d7f'), ObjectId('66ecd774cdceed4ae0773d80'), ObjectId('66ecd774cdceed4ae0773d81'), ObjectId('66ecd774cdceed4ae0773d82'), ObjectId('66ecd774cdceed4ae0773d83'), ObjectId('66ecd774cdceed4ae0773d84'), ObjectId('66ecd774cdceed4ae0773d85'), ObjectId('66ecd774cdceed4ae0773d86'), ObjectId('66ecd774cdceed4ae0773d87'), ObjectId('66ecd774cdceed4ae0773d88'), ObjectId('66ecd774cdceed4ae0773d89'), ObjectId('66ecd774cdceed4ae0773d8a'), ObjectId('66ecd774cdceed4ae0773d8b'), ObjectId('66ecd774cdceed4ae0773d8c'), ObjectId('66ecd774cdceed4ae0773d8d'), ObjectId('66ecd774cdceed4ae0773d8e'), ObjectId('66ecd774cdceed4ae0773d8f'), ObjectId('66ecd774cdceed4ae0773d90'), ObjectId('66ecd774cdceed4ae0773d91'), ObjectId('66ecd774cdceed4ae0773d92'), ObjectId('66ecd774cdceed4ae0773d93'), ObjectId('66ecd774cdceed4ae0773d94'), ObjectId('66ecd774cdceed4ae0773d95'), ObjectId('66ecd774cdceed4ae0773d96'), ObjectId('66ecd774cdceed4ae0773d97'), ObjectId('66ecd774cdceed4ae0773d98'), ObjectId('66ecd774cdceed4ae0773d99'), ObjectId('66ecd774cdceed4ae0773d9a'), ObjectId('66ecd774cdceed4ae0773d9b'), ObjectId('66ecd774cdceed4ae0773d9c'), ObjectId('66ecd774cdceed4ae0773d9d'), ObjectId('66ecd774cdceed4ae0773d9e'), ObjectId('66ecd774cdceed4ae0773d9f'), ObjectId('66ecd774cdceed4ae0773da0'), ObjectId('66ecd774cdceed4ae0773da1'), ObjectId('66ecd774cdceed4ae0773da2'), ObjectId('66ecd774cdceed4ae0773da3'), ObjectId('66ecd774cdceed4ae0773da4'), ObjectId('66ecd774cdceed4ae0773da5'), ObjectId('66ecd774cdceed4ae0773da6'), ObjectId('66ecd774cdceed4ae0773da7'), ObjectId('66ecd774cdceed4ae0773da8'), ObjectId('66ecd774cdceed4ae0773da9'), ObjectId('66ecd774cdceed4ae0773daa'), ObjectId('66ecd774cdceed4ae0773dab'), ObjectId('66ecd774cdceed4ae0773dac'), ObjectId('66ecd774cdceed4ae0773dad'), ObjectId('66ecd774cdceed4ae0773dae'), ObjectId('66ecd774cdceed4ae0773daf'), ObjectId('66ecd774cdceed4ae0773db0'), ObjectId('66ecd774cdceed4ae077 ...

# %%
customer = collection_name.find({"customer_state":"NY"})

# %%
customer_df = pd.DataFrame(customer)

# %%
customer_df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
