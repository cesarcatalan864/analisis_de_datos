# %%
# !pip install SQLAlchemy==2.0.29 mysql-connector-python==8.3.0 mysqlclient==2.2.4
# Out:
#   Cell In[2], line 2
#     mysql-connector-python==8.3.0
#                                ^
# SyntaxError: invalid syntax

# %%
# !pip install SQLAlchemy==2.0.29 mysql-connector-python==8.3.0 mysqlclient==2.2.4
# Out:
# Requirement already satisfied: SQLAlchemy==2.0.29 in /usr/local/python/3.12.1/lib/python3.12/site-packages (2.0.29)
# Collecting mysql-connector-python==8.3.0
#   Downloading mysql_connector_python-8.3.0-cp312-cp312-manylinux_2_17_x86_64.whl.metadata (1.9 kB)
# Collecting mysqlclient==2.2.4
#   Downloading mysqlclient-2.2.4.tar.gz (90 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: typing-extensions>=4.6.0 in /home/codespace/.local/lib/python3.12/site-packages (from SQLAlchemy==2.0.29) (4.9.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from SQLAlchemy==2.0.29) (3.1.0)
# Downloading mysql_connector_python-8.3.0-cp312-cp312-manylinux_2_17_x86_64.whl (21.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 86.2 MB/s eta 0:00:00:00:01
# Building wheels for collected packages: mysqlclient
#   Building wheel for mysqlclient (pyproject.toml) ... done
#   Created wheel for mysqlclient: filename=mysqlclient-2.2.4-cp312-cp312-linux_x86_64.whl size=135990 sha256=a56e1b504d89d40f472592322a4043d39902474790960f0f038c56805b0c19c5
#   Stored in directory: /home/codespace/.cache/pip/wheels/20/6f/c3/3b23bb01988b1c0bea0668e2116315ce43ced2179724ab593e
# Successfully built mysqlclient
# Installing collected packages: mysqlclient, mysql-connector-python
# Successfully installed mysql-connector-python-8.3.0 mysqlclient-2.2.4

# %%
import pandas as pd
import sqlalchemy as db 
import sqlalchemy as text

# %%
engine =db.create_engine("mysql://root:root@127.0.0.1:3310/retail_db")
conn = engine.connect()

# %%
df = pd.read_sql_query('select * from customers',con=conn)
df.head()
# Out:
#    customer_id customer_fname customer_lname customer_email customer_password  \
# 0            1        Richard      Hernandez      XXXXXXXXX         XXXXXXXXX
# 1            2           Mary        Barrett      XXXXXXXXX         XXXXXXXXX
# 2            3            Ann          Smith      XXXXXXXXX         XXXXXXXXX
# 3            4           Mary          Jones      XXXXXXXXX         XXXXXXXXX
# 4            5         Robert         Hudson      XXXXXXXXX         XXXXXXXXX
#
#            customer_street customer_city customer_state customer_zipcode
# 0       6303 Heather Plaza   Brownsville             TX            78521
# 1  9526 Noble Embers Ridge     Littleton             CO            80126
# 2   3422 Blue Pioneer Bend        Caguas             PR            00725
# 3       8324 Little Common    San Marcos             CA            92069
# 4   10 Crystal River Mall         Caguas             PR            00725

# %%
pd.read_sql('customers',con=conn)
# Out:
#        customer_id customer_fname customer_lname customer_email  \
# 0                1        Richard      Hernandez      XXXXXXXXX
# 1                2           Mary        Barrett      XXXXXXXXX
# 2                3            Ann          Smith      XXXXXXXXX
# 3                4           Mary          Jones      XXXXXXXXX
# 4                5         Robert         Hudson      XXXXXXXXX
# ...            ...            ...            ...            ...
# 12430        12431           Mary           Rios      XXXXXXXXX
# 12431        12432         Angela          Smith      XXXXXXXXX
# 12432        12433       Benjamin         Garcia      XXXXXXXXX
# 12433        12434           Mary          Mills      XXXXXXXXX
# 12434        12435          Laura         Horton      XXXXXXXXX
#
#       customer_password             customer_street customer_city  \
# 0             XXXXXXXXX          6303 Heather Plaza   Brownsville
# 1             XXXXXXXXX     9526 Noble Embers Ridge     Littleton
# 2             XXXXXXXXX      3422 Blue Pioneer Bend        Caguas
# 3             XXXXXXXXX          8324 Little Common    San Marcos
# 4             XXXXXXXXX      10 Crystal River Mall         Caguas
# ...                 ...                         ...           ...
# 12430         XXXXXXXXX           1221 Cinder Pines       Kaneohe
# 12431         XXXXXXXXX  1525 Jagged Barn Highlands        Caguas
# 12432         XXXXXXXXX    5459 Noble Brook Landing     Levittown
# 12433         XXXXXXXXX        9720 Colonial Parade        Caguas
# 12434         XXXXXXXXX            5736 Honey Downs   Summerville
#
#       customer_state customer_zipcode
# 0                 TX            78521
# 1                 CO            80126
# 2                 PR            00725
# 3                 CA            92069
# 4                 PR            00725
# ...              ...              ...
# 12430             HI            96744
# 12431             PR            00725
# 12432             NY            11756
# 12433             PR            00725
# 12434             SC            29483
#
# [12435 rows x 9 columns]

# %% [markdown]
# Leer datos MongoDB
